# %% [markdown]
# <a href="https://colab.research.google.com/github/langkh/colabDatasetProjects/blob/main/Python5eClass1_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PANDAS = Python Analysis Of Data

# %%
import pandas as pd

# %%
path = "https://raw.githubusercontent.com/yumio/data/main/population_by_country_2020.csv"

# %%
df = pd.read_csv(path)

# %% [markdown]
# df= Data Frame (means table here)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.3+ KB

# %%
df
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
pd.set_option('display.max_rows',235)

# %%
pd.reset_option('display.max_rows')

# %%
pd.set_option('display.max_rows',235)

# %%
df

# %%
df.sort_values(by=['Med. Age'], ascending = False)
# Out:
#       Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 234                  Holy See                801        0.25 %           2
# 218                 Gibraltar              33689       -0.03 %         -10
# 216             Liechtenstein              38147        0.29 %         109
# 215              Saint Martin              38778        1.75 %         664
# 214          Turks and Caicos              38806        1.38 %         526
# 213                    Monaco              39290        0.71 %         278
# 212              Sint Maarten              42960        1.15 %         488
# 211            Faeroe Islands              48896        0.38 %         185
# 210       Saint Kitts & Nevis              53264        0.71 %         376
# 209            American Samoa              55169       -0.22 %        -121
# 208                 Greenland              56787        0.17 %          98
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df['Med. Age'] = pd.to_numeric(df['Med. Age'] , errors = 'coerce')

# %%
df.sort_values(by=['Med. Age'], ascending = True)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 55                    Niger           24346468        3.84 %      895929
# 59                     Mali           20346106        3.02 %      592802
# 71                     Chad           16502877        3.00 %      478988
# 72                  Somalia           15965848        2.92 %      450317
# 43                   Angola           33032075        3.27 %     1040977
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate  Med. Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 201 non-null    float64
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 20.3+ KB

# %%
df['Urban Pop %'] = df['Urban Pop %'].str.strip('%')

# %%
df['Urban Pop %'] = pd.to_numeric(df['Urban Pop %'], errors = 'coerce')

# %%
df.sort_values(by=['Urban Pop %'], ascending = False)

# %%
df['World Share'] = df['World Share'].str.strip('%')

# %%
df['World Share'] = pd.to_numeric(df['World Share'], errors = 'coerce')

# %%
df.sort_values(by=['World Share'], ascending = False)

# %%
df['Yearly Change'] = df['Yearly Change'].str.strip('%')

# %%
df['Yearly Change'] = pd.to_numeric(df['Yearly Change'], errors = 'coerce')

# %%
df.sort_values(by=['Yearly Change'], ascending = False)

# %%
df['Fert. Rate'] = df['Fert. Rate'].str.strip('%')

# %%
df['Fert. Rate'] = pd.to_numeric(df['Fert. Rate'], errors = 'coerce')

# %%
df.sort_values(by=['Fert. Rate'], ascending = False)

# %%
df.info()

# %%
df.sort_values(by=['Fert. Rate'], ascending = False)
# Out:
#     Country (or dependency)  Population (2020)  ...  Urban Pop %  World Share
# 55                    Niger           24346468  ...         17.0         0.31
# ..                      ...                ...  ...          ...          ...
# 234                Holy See                801  ...          NaN         0.00
#
# [235 rows x 11 columns]

# %%
pd.set_option('display.max_rows',10)

# %%
df.sort_values(by=['Net Change'], ascending = False)
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 1                    India         1382345085        0.99 %    13586631
# 0                    China         1440297825        0.39 %     5540090
# 6                  Nigeria          206984347        2.58 %     5175990
# 4                 Pakistan          221612785        2.00 %     4327022
# 3                Indonesia          274021604        1.07 %     2898047
# ..                     ...                ...           ...         ...
# 49               Venezuela           28421581       -0.28 %      -79889
# 22                   Italy           60446035       -0.15 %      -88249
# 60                 Romania           19214608       -0.66 %     -126866
# 34                 Ukraine           43686577       -0.59 %     -259876
# 10                   Japan          126407422       -0.30 %     -383840
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate  Med. Age  \
# ...

# %%
df.sort_values(by=['Migrants (net)'], ascending = False)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 2             United States          331341050        0.59 %     1937734
# 18                  Germany           83830972        0.32 %      266897
# 16                   Turkey           84495243        1.09 %      909452
# 20           United Kingdom           67948282        0.53 %      355839
# 38                   Canada           37799407        0.89 %      331107
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate  Med. Age  \
# ...

# %% [markdown]
# The top ten countries are not the same because net change is when you subtract the emigrants from the migrants and migrants are temporary, not like imagrants.

# %% [markdown]
# Homework Question: Display the Top 10 Countries for Net Change and Top 10 Countries for Migrants.
# Use Text field and explain in one or two sentences why those top 10 countries are not the same.
